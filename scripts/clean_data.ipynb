# %%
import pandas as pd
import os
import numpy as np

# %%
df_2023 = pd.read_csv('../data/raw/csv/fallas_cerradas_fibra_optica_2023.csv')
df_2024 = pd.read_csv('../data/raw/csv/fallas_cerradas_fibra_optica_2024.csv')
df_2025 = pd.read_csv('../data/raw/csv/fallas_cerradas_fibra_optica_2025.csv')
df = pd.concat([df_2023, df_2024, df_2025])

df.head(10)
# Out:
#    recid    NUMERO         TAREA     CATEGORY SUBCATEGORY COMPANY  \
# 0      1  F4866407  F4866407-001  TRANSMISION        DWDM  TELGUA
# 1      2  F4866413  F4866413-001        DATOS      ROUTER  TELGUA
# 2      3  F4866465  F4866465-001        DATOS      ROUTER  TELGUA
# 3      4  F4866489           NaN  TRANSMISION        DWDM  TELGUA
# 4      5  F4866542  F4866542-002  TRANSMISION        DWDM  TELGUA
# 5      6  F4867009  F4867009-002        DATOS      SWITCH  TELGUA
# 6      7  F4867334  F4867334-001  TRANSMISION  RADIOS SDH  TELGUA
# 7      8  F4867426  F4867426-001        DATOS      SWITCH  TELGUA
# 8      9  F4867708           NaN        DATOS      ROUTER  TELGUA
# 9     10  F4867785           NaN        DATOS      ROUTER  TELGUA
#
#           INICIO_FALLA         CIERRE_FALLA  TIEMPO_TOTAL    COUNTRY  ...  \
# 0  01/01/2023 00:02:37  01/01/2023 12:23:27         12.35  Guatemala  ...
# 1  01/01/2023 00:10:17  01/01/2023 19:48:10         19.63  Guatemala  ...
# 2  01/01/2023 02:46:08  01/01/2023 14:44:16         11.97  Guatemala  ...
# 3  01/01/2023 03:44:23  01/01/2023 06:54:45          3.17  Guatemala  ...
# 4  01/01/2023 07:06:19  01/01/2023 15:31:41          8.42  Guatemala  ...
# 5  01/01/2023 20:56:01  02/01/2023 06:21:36          9.43  Guatemala  ...
# 6  02/01/2023 10:17:22  02/01/2023 18:50:34          8.55  Guatemala  ...
# 7  02/01/2023 11:41:08  02/01/2023 18:39:02          6.97  Guatemala  ...
# 8  02/01/2023 15:47:17  02/01/2023 21:14:48          5.46  Guatemala  ...
# 9  02/01/2023 17:40:18  03/01/2023 01:58:23          8.30  Guatemala  ...
#
#   TG_CANT_CLIENTES_AFECTADOS TG_CANTIDAD_CELDAS Latitud_del_corte_de_FO  \
# 0                          1                0.0                     NaN
# 1                          0               45.0       no se tiene datos
# 2                          1                0.0                     NaN
# 3                          1                0.0                       .
# 4                          0                1.0                     NaN
# 5                          1                0.0                       .
# 6                          1                0.0               15.968199
# 7                          1                8.0               14.067721
# 8                          0                0.0               14.583170
# 9                          0                0.0               14.729468
#
#   Longitud_del_corte_de_FO          Tipo Falla_de_Fibra_Óptica  \
# 0                      NaN        ACCESO                    SI
# 1        no se tiene datos        ACCESO                    SI
# 2                      NaN        ACCESO                    SI
# 3                        .  ULTIMA MILLA                    SI
# 4                      NaN      BACKBONE                    SI
# 5                        .        ACCESO                    SI
# 6              -90.2915933  ULTIMA MILLA                    SI
# 7               -90.380683        ACCESO                    SI
# 8               -90.660773      BACKBONE                    SI
# 9               -90.658512      BACKBONE                    SI
#
#                              Reparación_Principal_FO  \
# 0  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 1  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 2  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 3  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 4  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 5  2.HILOS FO ROTOS/ MAL ACOMODO DE HILOS EN BAND...
# 6  2.HILOS FO ROTOS/ MAL ACOMODO DE HILOS EN BAND...
# 7  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 8  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 9  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
#
#                             Reparación_específica_FO  \
# 0  3.4 INSTALACION DE CABLE FO AEREO FIG 8, DE 12...
# 1  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...
# 2  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 3  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...
# 4  3.3 INSTALACION DE CABLE DE FO DUCTO DE 96 HAS...
# 5  2.1 INTERVENCION A MUFA O CIERRE FO/NAP/HUB BO...
# 6  2.1 INTERVENCION A MUFA O CIERRE FO/NAP/HUB BO...
# 7  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...
# 8  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...
# 9  1.2 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...
#
#                              Tramo_de_FO Tramo_sin_Documentar
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                   SEMOX-MODESTO MENDEZ                  NaN
# 4                                    NaN                  NaN
# 5                                    NaN                  NaN
# 6                                    NaN                  NaN
# 7   CENTRAL CHIQUIMULILLA-CRUCE CERRITOS                  NaN
# 8  SAN LUCAS SACATEPEQUEZ-FINCA LA LABOR                  NaN
# 9                            WG3713G1900                  NaN
#
# [10 rows x 49 columns]

# %%
df.tail(10)
# Out:
#     recid    NUMERO         TAREA     CATEGORY   SUBCATEGORY COMPANY  \
# 35     36  F6124865  F6124865-002        DATOS        ROUTER  TELGUA
# 36     37  F6124889  F6124889-002        MOVIL           BTS  TELGUA
# 37     38  F6125749  F6125749-002  TRANSMISION  FIBRA OPTICA  TELGUA
# 38     39  F6125989  F6125989-002        DATOS        SWITCH  TELGUA
# 39     40  F6126044  F6126044-002        MOVIL           LTE  TELGUA
# 40     41  F6126181  F6126181-002        MOVIL           LTE  TELGUA
# 41     42  F6126341  F6126341-001  TRANSMISION          DWDM  TELGUA
# 42     43  F6126912  F6126912-002  TRANSMISION          DWDM  TELGUA
# 43     44  F6127575           NaN     CLARO TV       RED HFC  TELGUA
# 44     45  F6127953  F6127953-002        MOVIL           BSC  TELGUA
#
#            INICIO_FALLA         CIERRE_FALLA  TIEMPO_TOTAL    COUNTRY  ...  \
# 35  11/06/2025 04:33:50  11/06/2025 10:20:53          5.78  Guatemala  ...
# 36  11/06/2025 04:58:22  11/06/2025 13:27:27          8.48  Guatemala  ...
# 37  11/06/2025 10:45:27  11/06/2025 22:28:36         11.72  Guatemala  ...
# 38  11/06/2025 11:56:23  11/06/2025 15:20:11          3.40  Guatemala  ...
# 39  11/06/2025 12:15:51  11/06/2025 17:49:38          5.56  Guatemala  ...
# 40  11/06/2025 13:06:54  11/06/2025 23:45:42         10.65  Guatemala  ...
# 41  11/06/2025 14:20:29  12/06/2025 04:06:09         13.76  Guatemala  ...
# 42  11/06/2025 19:27:23  12/06/2025 09:54:13         14.45  Guatemala  ...
# 43  12/06/2025 07:53:43  12/06/2025 14:59:04          7.09  Guatemala  ...
# 44  12/06/2025 10:28:14  12/06/2025 16:44:19          6.27  Guatemala  ...
#
#    TG_CANT_CLIENTES_AFECTADOS TG_CANTIDAD_CELDAS Latitud_del_corte_de_FO  \
# 35                          0                1.0               14.027082
# 36                          0                1.0                 15.5650
# 37                        120                0.0     NO BRINDA PROVEEDOR
# 38                          1                0.0             14.29100184
# 39                          0                1.0                 16.0246
# 40                          0               38.0     NO BRINDA PROVEEDOR
# 41                          0                0.0        NO BRINDA UFINET
# 42                          1                0.0               NO INDICA
# 43                         50                0.0               14.706626
# 44                          0                0.0                14.72660
#
#    Longitud_del_corte_de_FO          Tipo Falla_de_Fibra_Óptica  \
# 35               -91.096926        ACCESO                    SI
# 36                 -88.9160  ULTIMA MILLA                    SI
# 37      NO BRINDA PROVEEDOR      BACKBONE                    SI
# 38             -89.92696747        ACCESO                    SI
# 39                 -91.7127      BACKBONE                    SI
# 40      NO BRINDA PROVEEDOR        ACCESO                    SI
# 41         NO BRINDA UFINET  ULTIMA MILLA                    SI
# 42                NO INDICA      BACKBONE                    SI
# 43               -90.480764  ULTIMA MILLA                    SI
# 44                -92.03368  ULTIMA MILLA                    SI
#
#                               Reparación_Principal_FO  \
# 35  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 36  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 37  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 38  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 39  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 40  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 41  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 42  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 43  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 44  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
#
#                              Reparación_específica_FO  \
# 35  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 36  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 37  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 38  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 39  3.4 INSTALACION DE CABLE FO AEREO FIG 8, DE 12...
# 40  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 41  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...
# 42  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...
# 43        3.1 INSTALACION DE CABLE DE FO AOTV DE 6 FO
# 44  3.4 INSTALACION DE CABLE FO AEREO FIG 8, DE 12...
#
#                      Tramo_de_FO                         Tramo_sin_Documentar
# 35   UR LA GOMERA-CELDA SIPACATE                                          NaN
# 36          TRAMO NO DOCUMENTADO   BUENOS AIRES RIO DULCE Y ALDREA EL MILAGRO
# 37          TRAMO NO DOCUMENTADO                     ZACAPA LOS AMATES UFINET
# 38          TRAMO NO DOCUMENTADO                CENTRAL JUTIAPA HACIA CAULOTE
# 39          TRAMO NO DOCUMENTADO                   LA TRINIDAD-GRACIAS A DIOS
# 40          TRAMO NO DOCUMENTADO             El Estor-Claro Rio Dulce¿ ufinet
# 41          TRAMO NO DOCUMENTADO                      HUEHUETENANGO -- QUICHE
# 42  TECUN UMAN-COATEPEQUE_UFINET                                          NaN
# 43          TRAMO NO DOCUMENTADO                           UTATLAN-UTATLANF01
# 44          TRAMO NO DOCUMENTADO                       Ur Pajapita/Pajapita 2
#
# [10 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2955 entries, 0 to 44
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   recid                       2955 non-null   int64
#  1   NUMERO                      2955 non-null   object
#  2   TAREA                       2911 non-null   object
#  3   CATEGORY                    2955 non-null   object
#  4   SUBCATEGORY                 2955 non-null   object
#  5   COMPANY                     2927 non-null   object
#  6   INICIO_FALLA                2955 non-null   object
#  7   CIERRE_FALLA                2955 non-null   object
#  8   TIEMPO_TOTAL                2955 non-null   float64
#  9   COUNTRY                     2955 non-null   object
#  10  TG_REGION                   2955 non-null   object
#  11  LOCATION_FULL_NAME          2955 non-null   object
#  12  OPENED_BY                   2955 non-null   object
#  13  ASSIGN_DATE                 2950 non-null   object
#  14  ASSIGNMENT                  2955 non-null   object
#  15  ASSIGN_DEPT                 2955 non-null   object
#  16  GRUPO_ASIGNACION            1615 non-null   object
#  17  ASSIGNED_TO                 2955 non-null   object
#  18  BRIEF_DESCRIPTION           2955 non-null   object
#  19  PROBLEM_TYPE                2955 non-null   object
#  20  PRODUCT_TYPE                2955 non-null   object
#  21  INICIO_AFECTACION           2955 non-null   object
#  22  FIN_AFECTACION              2955 non-null   object
#  23  DESC_FALLA                  2955 non-null   object
#  24  SEVERITY                    2955 non-null   object
#  25  TG_CANTIDAD_DSLAM           2955 non-null   int64
#  26  TG_SEVERIDAD                2955 non-null   object
#  27  PROBLEM_STATUS              2955 non-null   object
#  28  RESOLVED_GROUP              2947 non-null   object
#  29  CLOSED_BY                   2955 non-null   object
#  30  RESOLUTION_CODE             2952 non-null   object
#  31  RES_ANAL_CODE               2955 non-null   object
#  32  STATUS                      2955 non-null   object
#  33  TG_CLIENTEEMPRESARIAL       2955 non-null   object
#  34  NOMBRE_WO                   0 non-null      float64
#  35  INICIO_WO                   0 non-null      float64
#  36  FIN_WO                      0 non-null      float64
#  37  CLOSE_TIME                  2955 non-null   object
#  38  RESOLUCION                  2955 non-null   object
#  39  TG_CANT_CLIENTES_AFECTADOS  2955 non-null   int64
#  40  TG_CANTIDAD_CELDAS          2954 non-null   float64
#  41  Latitud_del_corte_de_FO     2930 non-null   object
#  42  Longitud_del_corte_de_FO    2931 non-null   object
#  43  Tipo                        2955 non-null   object
#  44  Falla_de_Fibra_Óptica       2955 non-null   object
#  45  Reparación_Principal_FO     2955 non-null   object
#  46  Reparación_específica_FO    2955 non-null   object
#  47  Tramo_de_FO                 1470 non-null   object
#  48  Tramo_sin_Documentar        399 non-null    object
# dtypes: float64(5), int64(3), object(41)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (2955, 49)

# %%
for col in df.columns:
    if col.isupper():
        df.columns = df.columns.str.lower()

df.columns
# Out:
# Index(['recid', 'numero', 'tarea', 'category', 'subcategory', 'company',
#        'inicio_falla', 'cierre_falla', 'tiempo_total', 'country', 'tg_region',
#        'location_full_name', 'opened_by', 'assign_date', 'assignment',
#        'assign_dept', 'grupo_asignacion', 'assigned_to', 'brief_description',
#        'problem_type', 'product_type', 'inicio_afectacion', 'fin_afectacion',
#        'desc_falla', 'severity', 'tg_cantidad_dslam', 'tg_severidad',
#        'problem_status', 'resolved_group', 'closed_by', 'resolution_code',
#        'res_anal_code', 'status', 'tg_clienteempresarial', 'nombre_wo',
#        'inicio_wo', 'fin_wo', 'close_time', 'resolucion',
#        'tg_cant_clientes_afectados', 'tg_cantidad_celdas',
#        'latitud_del_corte_de_fo', 'longitud_del_corte_de_fo', 'tipo',
#        'falla_de_fibra_óptica', 'reparación_principal_fo',
#        'reparación_específica_fo', 'tramo_de_fo', 'tramo_sin_documentar'],
#       dtype='object')

# %%
df.rename({
    "numero": "id_ticket",
    "category": "categoria",
    "subcategory": "subcategoria",
    "company": "compania",
    "country": "pais",
    "location_full_name": "direccion",
    "opened_by": "abierto_por",
    "assign_date": "fecha_asignacion",
    "assignment": "equipo_asignado",
    "assign_dept": "departamento_asignado",
    "grupo_asignacion": "grupo_asignado",
    "assigned_to": "agente_asignado",
    "brief_description": "descripcion",
    "problem_type": "tipo_de_problema",
    "product_type": "tipo_de_producto",
    "severity": "severidad",
    "problem_status": "estatus_del_problema",
    "resolved_group": "grupo_que_resolvio",
    "closed_by": "cerrado_por",
    "resolution_code": "codigo_de_resolucion",
    "status": "estatus_del_ticket",
    "close_time": "tiempo_de_cierre",
}, inplace=True, axis=1)
df.head()
# Out:
#    recid id_ticket         tarea    categoria subcategoria compania  \
# 0      1  F4866407  F4866407-001  TRANSMISION         DWDM   TELGUA
# 1      2  F4866413  F4866413-001        DATOS       ROUTER   TELGUA
# 2      3  F4866465  F4866465-001        DATOS       ROUTER   TELGUA
# 3      4  F4866489           NaN  TRANSMISION         DWDM   TELGUA
# 4      5  F4866542  F4866542-002  TRANSMISION         DWDM   TELGUA
#
#           inicio_falla         cierre_falla  tiempo_total       pais  ...  \
# 0  01/01/2023 00:02:37  01/01/2023 12:23:27         12.35  Guatemala  ...
# 1  01/01/2023 00:10:17  01/01/2023 19:48:10         19.63  Guatemala  ...
# 2  01/01/2023 02:46:08  01/01/2023 14:44:16         11.97  Guatemala  ...
# 3  01/01/2023 03:44:23  01/01/2023 06:54:45          3.17  Guatemala  ...
# 4  01/01/2023 07:06:19  01/01/2023 15:31:41          8.42  Guatemala  ...
#
#   tg_cant_clientes_afectados tg_cantidad_celdas latitud_del_corte_de_fo  \
# 0                          1                0.0                     NaN
# 1                          0               45.0       no se tiene datos
# 2                          1                0.0                     NaN
# 3                          1                0.0                       .
# 4                          0                1.0                     NaN
#
#   longitud_del_corte_de_fo          tipo falla_de_fibra_óptica  \
# 0                      NaN        ACCESO                    SI
# 1        no se tiene datos        ACCESO                    SI
# 2                      NaN        ACCESO                    SI
# 3                        .  ULTIMA MILLA                    SI
# 4                      NaN      BACKBONE                    SI
#
#                              reparación_principal_fo  \
# 0  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 1  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 2  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
# 3  1.DAÑO / ROBO DE MUFA O CIERRE FO / FAT /HUB B...
# 4  3.CABLE FO CORTADO, DAÑO O ESTIRAMIENTO DEL CA...
#
#                             reparación_específica_fo           tramo_de_fo  \
# 0  3.4 INSTALACION DE CABLE FO AEREO FIG 8, DE 12...                   NaN
# 1  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...                   NaN
# 2  3.2 INSTALACION DE CABLE DE FO DUCTO DE 12 HAS...                   NaN
# 3  1.1 CAMBIO E INSTALACION DE MUFA O CIERRE OPTI...  SEMOX-MODESTO MENDEZ
# 4  3.3 INSTALACION DE CABLE DE FO DUCTO DE 96 HAS...                   NaN
#
#   tramo_sin_documentar
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 49 columns]

# %%
print(f"Total rows before: {len(df)}")
print(f"Duplicated rows: {df.duplicated().sum()}")

df.drop_duplicates(inplace=True)

print(f"Total rows after: {len(df)}")
print(f"Rows removed: {len(df) - (len(df) - df.duplicated().sum())}")
# Out:
# Total rows before: 2955
# Duplicated rows: 0
# Total rows after: 2955
# Rows removed: 0

# %%
df["pais"].value_counts()
# Out:
# pais
# Guatemala    2955
# Name: count, dtype: int64

# %%
df.drop([
        'inicio_wo',
        'nombre_wo',
        'fin_wo',
        'pais',
        'compania',
        'tramo_de_fo',
        'tramo_sin_documentar',
        'tarea',
        'latitud_del_corte_de_fo',
        'longitud_del_corte_de_fo',
        'recid',
        'tg_clienteempresarial',
        'estatus_del_problema',
        'departamento_asignado'],
axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# id_ticket                        0
# categoria                        0
# subcategoria                     0
# inicio_falla                     0
# cierre_falla                     0
# tiempo_total                     0
# tg_region                        0
# direccion                        0
# abierto_por                      0
# fecha_asignacion                 5
# equipo_asignado                  0
# grupo_asignado                1340
# agente_asignado                  0
# descripcion                      0
# tipo_de_problema                 0
# tipo_de_producto                 0
# inicio_afectacion                0
# fin_afectacion                   0
# desc_falla                       0
# severidad                        0
# tg_cantidad_dslam                0
# tg_severidad                     0
# grupo_que_resolvio               8
# cerrado_por                      0
# codigo_de_resolucion             3
# res_anal_code                    0
# estatus_del_ticket               0
# tiempo_de_cierre                 0
# resolucion                       0
# tg_cant_clientes_afectados       0
# tg_cantidad_celdas               1
# tipo                             0
# falla_de_fibra_óptica            0
# reparación_principal_fo          0
# reparación_específica_fo         0
# dtype: int64

# %%
mask = df['grupo_asignado'].isna()
df.loc[mask, 'grupo_asignado'] = 'DESCONOCIDO'

# %%
grupo_que_resolvio_options = df["grupo_que_resolvio"].unique().tolist()
mask = df['grupo_que_resolvio'].isna()
df.loc[mask, 'grupo_que_resolvio'] = 'DESCONOCIDO'

# %%
df.isna().sum()
# Out:
# id_ticket                     0
# categoria                     0
# subcategoria                  0
# inicio_falla                  0
# cierre_falla                  0
# tiempo_total                  0
# tg_region                     0
# direccion                     0
# abierto_por                   0
# fecha_asignacion              5
# equipo_asignado               0
# grupo_asignado                0
# agente_asignado               0
# descripcion                   0
# tipo_de_problema              0
# tipo_de_producto              0
# inicio_afectacion             0
# fin_afectacion                0
# desc_falla                    0
# severidad                     0
# tg_cantidad_dslam             0
# tg_severidad                  0
# grupo_que_resolvio            0
# cerrado_por                   0
# codigo_de_resolucion          3
# res_anal_code                 0
# estatus_del_ticket            0
# tiempo_de_cierre              0
# resolucion                    0
# tg_cant_clientes_afectados    0
# tg_cantidad_celdas            1
# tipo                          0
# falla_de_fibra_óptica         0
# reparación_principal_fo       0
# reparación_específica_fo      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# id_ticket                     0
# categoria                     0
# subcategoria                  0
# inicio_falla                  0
# cierre_falla                  0
# tiempo_total                  0
# tg_region                     0
# direccion                     0
# abierto_por                   0
# fecha_asignacion              0
# equipo_asignado               0
# grupo_asignado                0
# agente_asignado               0
# descripcion                   0
# tipo_de_problema              0
# tipo_de_producto              0
# inicio_afectacion             0
# fin_afectacion                0
# desc_falla                    0
# severidad                     0
# tg_cantidad_dslam             0
# tg_severidad                  0
# grupo_que_resolvio            0
# cerrado_por                   0
# codigo_de_resolucion          0
# res_anal_code                 0
# estatus_del_ticket            0
# tiempo_de_cierre              0
# resolucion                    0
# tg_cant_clientes_afectados    0
# tg_cantidad_celdas            0
# tipo                          0
# falla_de_fibra_óptica         0
# reparación_principal_fo       0
# reparación_específica_fo      0
# dtype: int64

# %%
df.shape
# Out:
# (2946, 35)

# %% [markdown]
# ## Converting Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2946 entries, 0 to 44
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_ticket                   2946 non-null   object
#  1   categoria                   2946 non-null   object
#  2   subcategoria                2946 non-null   object
#  3   inicio_falla                2946 non-null   object
#  4   cierre_falla                2946 non-null   object
#  5   tiempo_total                2946 non-null   float64
#  6   tg_region                   2946 non-null   object
#  7   direccion                   2946 non-null   object
#  8   abierto_por                 2946 non-null   object
#  9   fecha_asignacion            2946 non-null   object
#  10  equipo_asignado             2946 non-null   object
#  11  grupo_asignado              2946 non-null   object
#  12  agente_asignado             2946 non-null   object
#  13  descripcion                 2946 non-null   object
#  14  tipo_de_problema            2946 non-null   object
#  15  tipo_de_producto            2946 non-null   object
#  16  inicio_afectacion           2946 non-null   object
#  17  fin_afectacion              2946 non-null   object
#  18  desc_falla                  2946 non-null   object
#  19  severidad                   2946 non-null   object
#  20  tg_cantidad_dslam           2946 non-null   int64
#  21  tg_severidad                2946 non-null   object
#  22  grupo_que_resolvio          2946 non-null   object
#  23  cerrado_por                 2946 non-null   object
#  24  codigo_de_resolucion        2946 non-null   object
#  25  res_anal_code               2946 non-null   object
#  26  estatus_del_ticket          2946 non-null   object
#  27  tiempo_de_cierre            2946 non-null   object
#  28  resolucion                  2946 non-null   object
#  29  tg_cant_clientes_afectados  2946 non-null   int64
#  30  tg_cantidad_celdas          2946 non-null   float64
#  31  tipo                        2946 non-null   object
#  32  falla_de_fibra_óptica       2946 non-null   object
#  33  reparación_principal_fo     2946 non-null   object
#  34  reparación_específica_fo    2946 non-null   object
# dtypes: float64(2), int64(2), object(31)
# memory usage: 828.6+ KB

# %%
category_columns = ["categoria",
                    "subcategoria",
                    "tg_region",
                    "equipo_asignado",
                    "grupo_asignado",
                    "tipo_de_problema",
                    "tipo_de_producto",
                    "severidad",
                    "grupo_que_resolvio",
                    "tipo"]
df["severidad"].unique().tolist()
# Out:
# ['1', '2', '3', '4', '1 - Crítica', '4 - Baja', '3 - Media', 1, 3, 4]

# %%
df["severidad"] = df["severidad"].astype(str)
df["severidad"] = df["severidad"].str.replace("1", "Critica").replace("2", "Alta").replace("3", "Media").replace("4", "Baja")
df["severidad"] = df["severidad"].str.replace("Critica - Crítica", "Critica").replace("4 - Baja", "Baja").replace("3 - Media", "Media")
df["severidad"].value_counts()
# Out:
# severidad
# Critica    2105
# Media       372
# Alta        266
# Baja        203
# Name: count, dtype: int64

# %%
for col in category_columns:
    df[col] = df[col].astype("category")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2946 entries, 0 to 44
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_ticket                   2946 non-null   object
#  1   categoria                   2946 non-null   category
#  2   subcategoria                2946 non-null   category
#  3   inicio_falla                2946 non-null   object
#  4   cierre_falla                2946 non-null   object
#  5   tiempo_total                2946 non-null   float64
#  6   tg_region                   2946 non-null   category
#  7   direccion                   2946 non-null   object
#  8   abierto_por                 2946 non-null   object
#  9   fecha_asignacion            2946 non-null   object
#  10  equipo_asignado             2946 non-null   category
#  11  grupo_asignado              2946 non-null   category
#  12  agente_asignado             2946 non-null   object
#  13  descripcion                 2946 non-null   object
#  14  tipo_de_problema            2946 non-null   category
#  15  tipo_de_producto            2946 non-null   category
#  16  inicio_afectacion           2946 non-null   object
#  17  fin_afectacion              2946 non-null   object
#  18  desc_falla                  2946 non-null   object
#  19  severidad                   2946 non-null   category
#  20  tg_cantidad_dslam           2946 non-null   int64
#  21  tg_severidad                2946 non-null   object
#  22  grupo_que_resolvio          2946 non-null   category
#  23  cerrado_por                 2946 non-null   object
#  24  codigo_de_resolucion        2946 non-null   object
#  25  res_anal_code               2946 non-null   object
#  26  estatus_del_ticket          2946 non-null   object
#  27  tiempo_de_cierre            2946 non-null   object
#  28  resolucion                  2946 non-null   object
#  29  tg_cant_clientes_afectados  2946 non-null   int64
#  30  tg_cantidad_celdas          2946 non-null   float64
#  31  tipo                        2946 non-null   category
#  32  falla_de_fibra_óptica       2946 non-null   object
#  33  reparación_principal_fo     2946 non-null   object
#  34  reparación_específica_fo    2946 non-null   object
# dtypes: category(10), float64(2), int64(2), object(21)
# memory usage: 633.3+ KB

# %%
datetime_columns = ["inicio_falla", "cierre_falla", "fecha_asignacion", "fin_afectacion"]
for col in datetime_columns:
    df[col] = pd.to_datetime(df[col], format="%d/%m/%Y %H:%M:%S")
    
df["tiempo_de_cierre"] = pd.to_datetime(df["tiempo_de_cierre"], format="%d-%b-%y")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2946 entries, 0 to 44
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id_ticket                   2946 non-null   object
#  1   categoria                   2946 non-null   category
#  2   subcategoria                2946 non-null   category
#  3   inicio_falla                2946 non-null   datetime64[ns]
#  4   cierre_falla                2946 non-null   datetime64[ns]
#  5   tiempo_total                2946 non-null   float64
#  6   tg_region                   2946 non-null   category
#  7   direccion                   2946 non-null   object
#  8   abierto_por                 2946 non-null   object
#  9   fecha_asignacion            2946 non-null   datetime64[ns]
#  10  equipo_asignado             2946 non-null   category
#  11  grupo_asignado              2946 non-null   category
#  12  agente_asignado             2946 non-null   object
#  13  descripcion                 2946 non-null   object
#  14  tipo_de_problema            2946 non-null   category
#  15  tipo_de_producto            2946 non-null   category
#  16  inicio_afectacion           2946 non-null   object
#  17  fin_afectacion              2946 non-null   datetime64[ns]
#  18  desc_falla                  2946 non-null   object
#  19  severidad                   2946 non-null   category
#  20  tg_cantidad_dslam           2946 non-null   int64
#  21  tg_severidad                2946 non-null   object
#  22  grupo_que_resolvio          2946 non-null   category
#  23  cerrado_por                 2946 non-null   object
#  24  codigo_de_resolucion        2946 non-null   object
#  25  res_anal_code               2946 non-null   object
#  26  estatus_del_ticket          2946 non-null   object
#  27  tiempo_de_cierre            2946 non-null   datetime64[ns]
#  28  resolucion                  2946 non-null   object
#  29  tg_cant_clientes_afectados  2946 non-null   int64
#  30  tg_cantidad_celdas          2946 non-null   float64
#  31  tipo                        2946 non-null   category
#  32  falla_de_fibra_óptica       2946 non-null   object
#  33  reparación_principal_fo     2946 non-null   object
#  34  reparación_específica_fo    2946 non-null   object
# dtypes: category(10), datetime64[ns](5), float64(2), int64(2), object(16)
# memory usage: 633.3+ KB

# %%
df.to_pickle("../data/processed/fallas_cerradas_fibra_optica.pkl")
